# %%
class minmax_q_agent():
    def __init__(self, discount_factor, num_episodes,alpha, environment):
        self.discount_factor = discount_factor
        self.num_episodes = num_episodes
        self.env = environment
        self.alpha = alpha
        self.scale = 20

    # Function for get single state
    def get_single_state(self, state):
        new_state = []
        for position in range(len(state)):
            new_value = (state[position] + 2)
            if new_value < 0 :
              new_value = 0
            if new_value > 4 :
              new_value = 4
            new_state.append(int(round(new_value, 0)))
        single_state = int(new_state[0]/0.2   - 1 )*self.scale + int(new_state[1]/0.2) -1

        return single_state






    def epsilon_greedy(self,Q, epsilon, n_actions, state, action2):

        if np.random.rand() < epsilon:
            action = np.random.randint(0, n_actions)
        else:
            action = np.argmax([Q[state][i][action2] for i in range(n_actions)])
        return action

    def sarsa(self,env, alpha, gamma,  episodes):

        n_states, n_actions =400,5
        Qa = np.zeros((400, 5, 5))
        Qb = np.zeros((400, 5, 5))
        epsilons = 0.5
        timestep_reward1 = []
        timestep_reward2 = []
        a2 = np.random.randint(0, n_actions)
        for episode in range(episodes):
            print(f"Episode: {episode}")
            observation, infos = env.reset(seed=42)
            s1, s2 = self.get_single_state(observation['adversary_0'].tolist()), self.get_single_state(observation['agent_0'].tolist())
            t = 0
            total_reward1 = 0
            total_reward2 = 0
            if (episode+1)% 1500 == 0 :
              epsilons *= 0.5
            while env.agents:
                a1 = self.epsilon_greedy(Qa, epsilons, n_actions, s1 , a2)
                a2 = self.epsilon_greedy(Qb, epsilons, n_actions, s2, a1)
                t += 1

                actions = {'adversary_0': 0, 'agent_0': 0}
                actions['adversary_0'] = a1
                actions['agent_0'] = a2
                s_, reward, terminations, truncations, infos = env.step(actions)

                s_1, s_2 =  self.get_single_state(observation['adversary_0'].tolist()),  self.get_single_state(observation['agent_0'].tolist())
                reward1, reward2 = reward["adversary_0"], reward["agent_0"]
                total_reward1 += reward1
                total_reward2 += reward2
                aa_ = np.argmax(np.min(Qb[s_2,:,:], axis=1))
                ab_ = np.argmax(np.min(Qa[s_1,:,:], axis=1))

                Qa[s1, a1, a2] = (1- alpha) *Qa[s1, a1, a2]  + alpha * ( reward1+ (gamma * Qa[s_1, aa_, ab_])  )
                Qb[s2, a2, a1] = (1 - alpha)* Qb[s2, a2, a1] + alpha * ( reward2 + (gamma * Qb[s_2,ab_, aa_])  )
                s1, s2=  s_1, s_2

            print(f"This episode took {t} timesteps and reward1: {total_reward1} reward2: {total_reward2}")

            timestep_reward1.append(total_reward1)
            timestep_reward2.append(total_reward2)

        return timestep_reward1, timestep_reward2



    def take_action(self):

        rewards = self.sarsa(self.env, self.alpha, self.discount_factor, self.num_episodes)

        return rewards

# %%
# !pip install gymnasium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\download_spotify_playlist-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\eyed3-0.9.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\spotipy-2.22.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\unidecode-1.3.6-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: pytorch-lightning 1.5.6 has a non-standard dependency specifier torch>=1.7.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gymnasium in c:\users\m.m\appdata\roaming\python\python311\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\m.m\appdata\roaming\python\python311\site-packages (from gymnasium) (1.26.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\m.m\appdata\roaming\python\python311\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\m.m\appdata\roaming\python\python311\site-packages (from gymnasium) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\m.m\appdata\roaming\python\python311\site-packages (from gymnasium) (0.0.4)

# %%
enum_action = { 0: "DO_nothing", 0: "LEFT", 1: "DOWN", 2: "RIGHT", 3: "UP" }


import gymnasium as gym
from gymnasium.utils.save_video import save_video
import numpy as np
import time


# hyperparameters
REPS = 20
EPISODES = 3000
EPSILON = 0.8
LEARNING_RATE = 0.1
DISCOUNT = 0.9
scale = 20

# %%
# !pip install 'pettingzoo[mpe]'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Invalid requirement: "'pettingzoo[mpe]'"
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pettingzoo.mpe import simple_adversary_v3,simple_v3


env = simple_adversary_v3.parallel_env(N=1 ,max_cycles=25, continuous_actions=False,render_mode="human")
env.reset(seed=42)
# Out:
# ({'adversary_0': array([-1.3595574 ,  1.0734879 ,  0.16928375,  0.51697916], dtype=float32),
#   'agent_0': array([-1.5288411 ,  0.55650866, -1.5288411 ,  0.55650866, -0.16928375,
#          -0.51697916], dtype=float32)},
#  {'adversary_0': {}, 'agent_0': {}})

# %%
for agent in env.agents:
    print(agent, env.observation_space(agent).shape[0])
    observ_space_num =env.observation_space(agent).shape[0]
# Out:
# adversary_0 4
# agent_0 6

# %%
for agent in env.agents:
    print(agent, env.action_space(agent).n)
    action_space_num =env.action_space(agent).n
# Out:
# adversary_0 5
# agent_0 5

# %%
# for agent in env.agents:
#     num_states =env.observation_space(agent).shape[0]
#     print(agent, env.observation_space(agent))
# print("Observatons", env.observation_space)
# for agent in env.agents:
#     num_actions =env.action_space(agent).n
#     print(agent, env.action_space(agent))
# # Initialize Q-table
# print("Initialize Q-table...")

# print("Number of states", num_states)
# print("Number of actions", num_actions)
# q_table = np.zeros((num_states, num_actions))
# print("Q-table", q_table.shape)

REPS = 20
EPISODES = 3000
EPSILON = 0.8
LEARNING_RATE = 0.01
DISCOUNT = 0.9
scale = 20

qlearn =minmax_q_agent(DISCOUNT,EPISODES,LEARNING_RATE,env)

# %%
import os
os.environ["SDL_VIDEODRIVER"] = "dummy"

# %%
r1_minmax, r2_minmax = qlearn.take_action()
# Out:
# Episode: 0
# This episode took 25 timesteps and reward1: -47.10293126161949 reward2: 6.700672845694447
# Episode: 1
# This episode took 25 timesteps and reward1: -42.43298512677612 reward2: -7.984076435627763
# Episode: 2
# This episode took 25 timesteps and reward1: -48.325552881829594 reward2: 16.078096819740246
# Episode: 3
# This episode took 25 timesteps and reward1: -35.11734030579979 reward2: -23.4318552600517
# Episode: 4
# This episode took 25 timesteps and reward1: -53.35910058640095 reward2: 2.207117816771389
# Episode: 5
# This episode took 25 timesteps and reward1: -36.93399281690668 reward2: -19.193547238552064
# Episode: 6
# This episode took 25 timesteps and reward1: -37.42790632486072 reward2: -0.34298790364955534
# Episode: 7
# This episode took 25 timesteps and reward1: -48.17331741003905 reward2: 10.908034373028038
# Episode: 8
# This episode took 25 timesteps and reward1: -42.932060092984834 reward2: 9.990434907543355
# Episode: 9
# This episode took 25 timesteps and reward1: -39.5339705639755 reward2: -1.747235318959519
# Episode: 10
# This episode took 25 timesteps and reward1: -41.8057775823487 reward2: 5.21709146501455
# Episode: 11
# This episode took 25 timesteps and reward1: -42.181883891164844 reward2: 19.39732070253951
# Episode: 12
# This episode took 25 timesteps and reward1: -44.979385444399725 reward2: 15.480869981150859
# Episode: 13
# This episode took 25 timesteps and reward1: -49.60832056038767 reward2: 23.061737924533332
# Episode: 14
# This episode took 25 timesteps and reward1: -48.29726044384241 reward2: -1.2651089261069142
# Episode: 15
# This episode took 25 timesteps and reward1: -40.428667176067975 reward2: 0.7693426901913749
# Episode: 16
# This episode took 25 timesteps and reward1: -56.478436715706046 reward2: 20.964358443419094
# Episode: 17
# This episode took 25 timesteps and reward1: -38.607352068748646 reward2: 4.200760752699911
# Episode: 18
# This episode took 25 timesteps and reward1: -39.2148924779591 reward2: 7.908339224476159
# Episode: 19
# This episode took 25 timesteps and reward1: -38.928502700702026 reward2: 5.247511956181549
# Episode: 20
# This episode took 25 timesteps and reward1: -49.65933120600702 reward2: 18.73820581413927
# Episode: 21
# This episode took 25 timesteps and reward1: -34.654504463837675 reward2: -0.8176147521510103
# Episode: 22
# This episode took 25 timesteps and reward1: -39.3037315922892 reward2: 5.210715591356149
# Episode: 23
# This episode took 25 timesteps and reward1: -47.758902382122926 reward2: 10.33482213414765
# Episode: 24
# This episode took 25 timesteps and reward1: -49.47138649470998 reward2: 19.936611735838753
# Episode: 25
# This episode took 25 timesteps and reward1: -39.88534603214197 reward2: 7.92306280684053
# Episode: 26
# This episode took 25 timesteps and reward1: -54.37552379848476 reward2: 25.577973251539092
# Episode: 27
# This episode took 25 timesteps and reward1: -51.37881705003749 reward2: 21.026713080440448
# Episode: 28
# This episode took 25 timesteps and reward1: -33.83748537803267 reward2: -6.520252524282046
# Episode: 29
# This episode took 25 timesteps and reward1: -52.349471063928675 reward2: 28.43055977505383
# Episode: 30
# This episode took 25 timesteps and reward1: -45.045737228091824 reward2: 11.465102921885327
# Episode: 31
# This episode took 25 timesteps and reward1: -53.073062064404866 reward2: 15.53989537828721
# Episode: 32
# This episode took 25 timesteps and reward1: -43.48365611672488 reward2: 15.946204539246889
# Episode: 33
# This episode took 25 timesteps and reward1: -38.66247358261254 reward2: 12.856447383062651
# Episode: 34
# This episode took 25 timesteps and reward1: -34.886582896229584 reward2: 5.312274420191885
# Episode: 35
# This episode took 25 timesteps and reward1: -39.98098046261475 reward2: 4.645500793773312
# Episode: 36
# This episode took 25 timesteps and reward1: -45.57091409627474 reward2: 20.601586094418316
# Episode: 37
# This episode took 25 timesteps and reward1: -47.76966804151783 reward2: 14.46590899016531
# Episode: 38
# This episode took 25 timesteps and reward1: -38.563896679282614 reward2: 7.465216172948402
# Episode: 39
# This episode took 25 timesteps and reward1: -44.40500538758514 reward2: 7.074747645954574
# Episode: 40
# This episode took 25 timesteps and reward1: -46.8932295915268 reward2: 6.947165110985395
# Episode: 41
# This episode took 25 timesteps and reward1: -37.83968995690806 reward2: -5.186192978350054
# Episode: 42
# This episode took 25 timesteps and reward1: -50.63444868058762 reward2: 11.480522432643504
# Episode: 43
# This episode took 25 timesteps and reward1: -51.38990164961312 reward2: 16.224478125323632
# Episode: 44
# This episode took 25 timesteps and reward1: -46.48632098531392 reward2: 17.499063021572947
# Episode: 45
# This episode took 25 timesteps and reward1: -37.86078595142277 reward2: 9.225126718247132
# Episode: 46
# This episode took 25 timesteps and reward1: -47.06261841522946 reward2: 3.9942666791857215
# Episode: 47
# This episode took 25 timesteps and reward1: -46.842654525969444 reward2: 8.94669523582408
# Episode: 48
# This episode took 25 timesteps and reward1: -50.93250503868545 reward2: 22.423130446283555
# Episode: 49
# This episode took 25 timesteps and reward1: -45.55517937945645 reward2: 16.065553266773758
# Episode: 50
# This episode took 25 timesteps and reward1: -47.640667503074845 reward2: 16.424180115441064
# Episode: 51
# This episode took 25 timesteps and reward1: -52.66975621549696 reward2: 23.262880925591276
# Episode: 52
# This episode took 25 timesteps and reward1: -45.76074960142103 reward2: 11.891122019324726
# Episode: 53
# This episode took 25 timesteps and reward1: -28.434074831152067 reward2: -9.899822838765784
# Episode: 54
# This episode took 25 timesteps and reward1: -36.8572536430848 reward2: 16.359401067291135
# Episode: 55
# This episode took 25 timesteps and reward1: -53.03377560395926 reward2: 24.88779100733456
# Episode: 56
# This episode took 25 timesteps and reward1: -42.53513233575628 reward2: 1.8665322081854254
# Episode: 57
# This episode took 25 timesteps and reward1: -39.04539185932107 reward2: 1.0332291844022352
# Episode: 58
# This episode took 25 timesteps and reward1: -51.13054364123698 reward2: 17.52451105387148
# Episode: 59
# This episode took 25 timesteps and reward1: -40.203276569443176 reward2: -3.8188597631500887
# Episode: 60
# This episode took 25 timesteps and reward1: -50.27378792882831 reward2: 20.419056261527462
# Episode: 61
# This episode took 25 timesteps and reward1: -38.41106134420933 reward2: 4.544096922818085
# Episode: 62
# This episode took 25 timesteps and reward1: -50.16923557362987 reward2: 18.485708768493165
# Episode: 63
# This episode took 25 timesteps and reward1: -43.61658778312033 reward2: -4.016977857074062
# Episode: 64
# This episode took 25 timesteps and reward1: -44.58565738343147 reward2: 20.643312237366782
# Episode: 65
# This episode took 25 timesteps and reward1: -42.586130912666334 reward2: 10.809432864200323
# Episode: 66
# This episode took 25 timesteps and reward1: -44.833937717730954 reward2: 13.812013949340312
# Episode: 67
# This episode took 25 timesteps and reward1: -45.34468350257459 reward2: 1.1332273008965326
# Episode: 68
# This episode took 25 timesteps and reward1: -43.9116792508506 reward2: 10.008640261189726
# Episode: 69
# This episode took 25 timesteps and reward1: -43.585848085679196 reward2: 16.067710843517894
# Episode: 70
# This episode took 25 timesteps and reward1: -39.176629322381594 reward2: -2.5815362992601765
# Episode: 71
# This episode took 25 timesteps and reward1: -48.645605350966235 reward2: 4.803452299661748
# Episode: 72
# This episode took 25 timesteps and reward1: -40.507914662479166 reward2: 8.637595391496895
# Episode: 73
# This episode took 25 timesteps and reward1: -44.132468883792384 reward2: 8.623857287096268
# Episode: 74
# This episode took 25 timesteps and reward1: -42.57696333072868 reward2: 2.66535877200442
# Episode: 75
# This episode took 25 timesteps and reward1: -40.34979945830001 reward2: 0.5926438032791088
# Episode: 76
# This episode took 25 timesteps and reward1: -40.89089981007299 reward2: 15.468300074975778
# Episode: 77
# This episode took 25 timesteps and reward1: -47.960002276674885 reward2: 12.049506852051287
# Episode: 78
# This episode took 25 timesteps and reward1: -46.88029478995096 reward2: -5.6090950041071626
# Episode: 79
# This episode took 25 timesteps and reward1: -44.93415105259355 reward2: 5.805061413388689
# Episode: 80
# This episode took 25 timesteps and reward1: -55.41399783559054 reward2: 28.213444747359187
# Episode: 81
# This episode took 25 timesteps and reward1: -34.264204732911914 reward2: 9.985709080556513
# Episode: 82
# This episode took 25 timesteps and reward1: -35.1489508594215 reward2: 8.58109737729567
# Episode: 83
# This episode took 25 timesteps and reward1: -35.82852913376668 reward2: 0.7851531265748974
# Episode: 84
# This episode took 25 timesteps and reward1: -43.295112108498536 reward2: 13.172391547179672
# Episode: 85
# This episode took 25 timesteps and reward1: -54.90730172967591 reward2: 25.785899339647663
# Episode: 86
# This episode took 25 timesteps and reward1: -40.7501349511986 reward2: 6.127993652391382
# Episode: 87
# This episode took 25 timesteps and reward1: -49.17386993867934 reward2: 13.949715801231207
# Episode: 88
# This episode took 25 timesteps and reward1: -45.60974682014095 reward2: 11.844055269293824
# Episode: 89
# This episode took 25 timesteps and reward1: -49.7114658580452 reward2: 10.865062902676362
# Episode: 90
# This episode took 25 timesteps and reward1: -52.1994529770298 reward2: 9.174779378256792
# Episode: 91
# This episode took 25 timesteps and reward1: -47.87828497535078 reward2: 18.107178329260794
# Episode: 92
# This episode took 25 timesteps and reward1: -50.728768881741125 reward2: 18.81542460648207
# Episode: 93
# This episode took 25 timesteps and reward1: -43.85868037024536 reward2: 8.281687806961845
# Episode: 94
# This episode took 25 timesteps and reward1: -49.261415534931935 reward2: 27.53385536422144
# Episode: 95
# This episode took 25 timesteps and reward1: -42.00065592196182 reward2: 5.045446034237526
# Episode: 96
# This episode took 25 timesteps and reward1: -44.085344271874696 reward2: 1.7909608537083461
# Episode: 97
# This episode took 25 timesteps and reward1: -42.119170624731275 reward2: -5.570705129095961
# Episode: 98
# This episode took 25 timesteps and reward1: -37.75098028836872 reward2: 6.08724343044125
# Episode: 99
# This episode took 25 timesteps and reward1: -47.969599229963904 reward2: 4.943431747421137
# Episode: 100
# This episode took 25 timesteps and reward1: -45.05839718487058 reward2: 10.403232727748879
# Episode: 101
# This episode took 25 timesteps and reward1: -47.75987373343118 reward2: 27.023605702461328
# Episode: 102
# This episode took 25 timesteps and reward1: -41.82428201279903 reward2: 5.447670394540385
# Episode: 103
# This episode took 25 timesteps and reward1: -36.84821824294471 reward2: -12.119888961039909
# Episode: 104
# This episode took 25 timesteps and reward1: -44.35850526026011 reward2: -1.9311313106090813
# Episode: 105
# This episode took 25 timesteps and reward1: -47.27318461410157 reward2: 13.080685617063056
# Episode: 106
# This episode took 25 timesteps and reward1: -52.875171898355326 reward2: 21.639164403525903
# Episode: 107
# This episode took 25 timesteps and reward1: -49.196562186558566 reward2: 4.1940884581362425
# Episode: 108
# This episode took 25 timesteps and reward1: -54.007718802840266 reward2: 11.242729223630239
# Episode: 109
# This episode took 25 timesteps and reward1: -34.1012130912431 reward2: -1.86530548331058
# Episode: 110
# This episode took 25 timesteps and reward1: -54.895474937256026 reward2: 12.08044705689529
# Episode: 111
# This episode took 25 timesteps and reward1: -30.231707578367683 reward2: -4.966800219788161
# Episode: 112
# This episode took 25 timesteps and reward1: -48.34867811916191 reward2: 10.6625129912299
# Episode: 113
# This episode took 25 timesteps and reward1: -56.09352518106603 reward2: 23.75292213812505
# Episode: 114
# This episode took 25 timesteps and reward1: -46.124486622851855 reward2: 3.2235467694285624
# Episode: 115
# This episode took 25 timesteps and reward1: -53.026021293621916 reward2: 20.733041594284526
# Episode: 116
# This episode took 25 timesteps and reward1: -48.14727682293565 reward2: 11.324433931475019
# Episode: 117
# This episode took 25 timesteps and reward1: -38.74536141529652 reward2: 10.728145230081521
# Episode: 118
# This episode took 25 timesteps and reward1: -53.08338737453718 reward2: 16.85593603332944
# Episode: 119
# This episode took 25 timesteps and reward1: -36.781034069936155 reward2: -6.969855375422
# Episode: 120
# This episode took 25 timesteps and reward1: -58.7899453378405 reward2: 22.623097767505328
# Episode: 121
# This episode took 25 timesteps and reward1: -54.93358099156984 reward2: 15.42546246069365
# Episode: 122
# This episode took 25 timesteps and reward1: -46.209051751313716 reward2: 9.033654209371461
# Episode: 123
# This episode took 25 timesteps and reward1: -54.71194746537498 reward2: 21.717498818669142
# Episode: 124
# This episode took 25 timesteps and reward1: -50.59813928818756 reward2: 18.865899373664536
# Episode: 125
# This episode took 25 timesteps and reward1: -44.8175304492347 reward2: 13.927627672837952
# Episode: 126
# This episode took 25 timesteps and reward1: -51.3698068810129 reward2: 17.53221051952272
# Episode: 127
# This episode took 25 timesteps and reward1: -60.40016504283374 reward2: 18.67870499544049
# Episode: 128
# This episode took 25 timesteps and reward1: -50.257162517061055 reward2: 11.931232115153236
# Episode: 129
# This episode took 25 timesteps and reward1: -58.71205264321908 reward2: 25.85764885519413
# Episode: 130
# This episode took 25 timesteps and reward1: -47.625809263919834 reward2: 9.959784451820248
# Episode: 131
# This episode took 25 timesteps and reward1: -50.25289189828197 reward2: 19.791695192830097
# Episode: 132
# This episode took 25 timesteps and reward1: -52.108123295100526 reward2: 15.744931051507855
# Episode: 133
# This episode took 25 timesteps and reward1: -49.919680305175895 reward2: 11.753054076548148
# Episode: 134
# This episode took 25 timesteps and reward1: -53.58525981892529 reward2: 18.416831554536
# Episode: 135
# This episode took 25 timesteps and reward1: -60.69879195546549 reward2: 25.02436875419288
# Episode: 136
# This episode took 25 timesteps and reward1: -46.65572399017715 reward2: 6.477021537852381
# Episode: 137
# This episode took 25 timesteps and reward1: -39.9082900055962 reward2: 1.777428285828462
# Episode: 138
# This episode took 25 timesteps and reward1: -49.735282504382965 reward2: 7.52912327588907
# Episode: 139
# This episode took 25 timesteps and reward1: -56.69705629023227 reward2: 14.95868407770385
# Episode: 140
# This episode took 25 timesteps and reward1: -45.74943535255196 reward2: 15.339672640775518
# Episode: 141
# This episode took 25 timesteps and reward1: -57.74172817021618 reward2: 17.39990018808456
# Episode: 142
# This episode took 25 timesteps and reward1: -51.22575794925842 reward2: 16.891471593647097
# Episode: 143
# This episode took 25 timesteps and reward1: -49.143309141562185 reward2: 7.995107369086818
# Episode: 144
# This episode took 25 timesteps and reward1: -39.74878580518424 reward2: 6.9889780000794905
# Episode: 145
# This episode took 25 timesteps and reward1: -52.42541731896986 reward2: 12.997888755074829
# Episode: 146
# This episode took 25 timesteps and reward1: -45.39118822913547 reward2: 17.519977167879112
# Episode: 147
# This episode took 25 timesteps and reward1: -49.89418245710744 reward2: 21.561979647494343
# Episode: 148
# This episode took 25 timesteps and reward1: -55.49711943532492 reward2: 19.320734235672795
# Episode: 149
# This episode took 25 timesteps and reward1: -56.14157247771907 reward2: 31.825767521078582
# Episode: 150
# This episode took 25 timesteps and reward1: -41.088355408323146 reward2: 7.980383435507765
# Episode: 151
# This episode took 25 timesteps and reward1: -60.434880758476986 reward2: 25.888778825335446
# Episode: 152
# This episode took 25 timesteps and reward1: -52.900711225597405 reward2: 22.53801587561849
# Episode: 153
# This episode took 25 timesteps and reward1: -43.36947239732022 reward2: 12.51526027263759
# Episode: 154
# This episode took 25 timesteps and reward1: -51.699861885905335 reward2: 16.653823978003842
# Episode: 155
# This episode took 25 timesteps and reward1: -32.496888207225304 reward2: -8.874659937619718
# Episode: 156
# This episode took 25 timesteps and reward1: -41.8821502527208 reward2: 8.402382442319993
# Episode: 157
# This episode took 25 timesteps and reward1: -53.59935623261492 reward2: 9.353358197547802
# Episode: 158
# This episode took 25 timesteps and reward1: -51.44353942690193 reward2: 14.50742378017835
# Episode: 159
# This episode took 25 timesteps and reward1: -49.7949496911144 reward2: 16.477866446773273
# Episode: 160
# This episode took 25 timesteps and reward1: -43.71342433387677 reward2: 14.403139562203329
# Episode: 161
# This episode took 25 timesteps and reward1: -44.58083617070101 reward2: -3.279087717116833
# Episode: 162
# This episode took 25 timesteps and reward1: -47.88839446221886 reward2: 14.97165403518122
# Episode: 163
# This episode took 25 timesteps and reward1: -40.61605786824051 reward2: 3.5927380446905905
# Episode: 164
# This episode took 25 timesteps and reward1: -48.89727950710868 reward2: 12.282423059502634
# Episode: 165
# This episode took 25 timesteps and reward1: -46.34895820376259 reward2: 18.525323909008833
# Episode: 166
# This episode took 25 timesteps and reward1: -49.28171266865686 reward2: 17.126344347209542
# Episode: 167
# This episode took 25 timesteps and reward1: -56.03097576991677 reward2: 14.326600771194961
# Episode: 168
# This episode took 25 timesteps and reward1: -40.04132401086189 reward2: 7.602045535591543
# Episode: 169
# This episode took 25 timesteps and reward1: -50.75149655681579 reward2: 13.369098852957242
# Episode: 170
# This episode took 25 timesteps and reward1: -39.47323926703087 reward2: -3.3776718116603077
# Episode: 171
# This episode took 25 timesteps and reward1: -33.466173936558555 reward2: 6.033978650232069
# Episode: 172
# This episode took 25 timesteps and reward1: -51.345991587965436 reward2: 20.38997461248797
# Episode: 173
# This episode took 25 timesteps and reward1: -43.248207075162064 reward2: 3.3781220474351246
# Episode: 174
# This episode took 25 timesteps and reward1: -55.42849432224387 reward2: 27.983079163327204
# Episode: 175
# This episode took 25 timesteps and reward1: -41.95208582781849 reward2: 6.133104948151088
# Episode: 176
# This episode took 25 timesteps and reward1: -45.27632888775084 reward2: 18.848810576889623
# Episode: 177
# This episode took 25 timesteps and reward1: -48.484495185899355 reward2: 16.89415869885113
# Episode: 178
# This episode took 25 timesteps and reward1: -43.988848490666655 reward2: 12.14478492907836
# Episode: 179
# This episode took 25 timesteps and reward1: -56.717110870181145 reward2: 11.002402372742111
# Episode: 180
# This episode took 25 timesteps and reward1: -52.74175145519938 reward2: 23.997233334417174
# Episode: 181
# This episode took 25 timesteps and reward1: -47.448426896678924 reward2: 10.200106512965153
# Episode: 182
# This episode took 25 timesteps and reward1: -47.48328271394685 reward2: 18.929023690981634
# Episode: 183
# This episode took 25 timesteps and reward1: -43.28804732899089 reward2: -0.7325530299052576
# Episode: 184
# This episode took 25 timesteps and reward1: -50.98884493081658 reward2: 16.097148098478108
# Episode: 185
# This episode took 25 timesteps and reward1: -37.90461561344707 reward2: 8.182348278595649
# Episode: 186
# This episode took 25 timesteps and reward1: -49.00518338510832 reward2: 11.552710873431153
# Episode: 187
# This episode took 25 timesteps and reward1: -52.874155119894056 reward2: 10.959255514875085
# Episode: 188
# This episode took 25 timesteps and reward1: -33.29265484162437 reward2: 6.210705441050743
# Episode: 189
# This episode took 25 timesteps and reward1: -43.75740758116097 reward2: 3.955730925451973
# Episode: 190
# This episode took 25 timesteps and reward1: -34.795779983805964 reward2: 0.11386363207224137
# Episode: 191
# This episode took 25 timesteps and reward1: -40.70683570596212 reward2: 9.991867894177684
# Episode: 192
# This episode took 25 timesteps and reward1: -41.86819566016513 reward2: 8.740921823371263
# Episode: 193
# This episode took 25 timesteps and reward1: -41.631715348355534 reward2: -3.871935358243971
# Episode: 194
# This episode took 25 timesteps and reward1: -39.96269981603835 reward2: 13.832333232104885
# Episode: 195
# This episode took 25 timesteps and reward1: -40.929688276584976 reward2: 4.033029003561775
# Episode: 196
# This episode took 25 timesteps and reward1: -48.031457512199395 reward2: 11.270026783676117
# Episode: 197
# This episode took 25 timesteps and reward1: -57.08583966107265 reward2: 18.45217192246328
# Episode: 198
# This episode took 25 timesteps and reward1: -53.572951952478036 reward2: 8.691408764326555
# Episode: 199
# This episode took 25 timesteps and reward1: -41.50624580508292 reward2: 2.6887279674117495
# Episode: 200
# This episode took 25 timesteps and reward1: -55.96369844025564 reward2: 21.811424203357163
# Episode: 201
# This episode took 25 timesteps and reward1: -53.510431470050484 reward2: 17.12147543037346
# Episode: 202
# This episode took 25 timesteps and reward1: -43.49207680929523 reward2: 13.722778876259154
# Episode: 203
# This episode took 25 timesteps and reward1: -42.988268077130996 reward2: 18.92739334347928
# Episode: 204
# This episode took 25 timesteps and reward1: -43.83766999809307 reward2: 4.6126953428304915
# Episode: 205
# This episode took 25 timesteps and reward1: -51.12158395864045 reward2: 14.913040072298784
# Episode: 206
# This episode took 25 timesteps and reward1: -40.592099579386065 reward2: 15.463066793521854
# Episode: 207
# This episode took 25 timesteps and reward1: -52.28845049553721 reward2: 21.838177224888582
# Episode: 208
# This episode took 25 timesteps and reward1: -39.684039484418626 reward2: 11.529919957029552
# Episode: 209
# This episode took 25 timesteps and reward1: -50.13058964524524 reward2: 8.317113583244623
# Episode: 210
# This episode took 25 timesteps and reward1: -43.56056697227992 reward2: 9.962736474095724
# Episode: 211
# This episode took 25 timesteps and reward1: -56.28254378461801 reward2: 17.092346736380517
# Episode: 212
# This episode took 25 timesteps and reward1: -44.82352313012611 reward2: 0.0974577769126237
# Episode: 213
# This episode took 25 timesteps and reward1: -45.143772405233975 reward2: 2.0894564037237657
# Episode: 214
# This episode took 25 timesteps and reward1: -41.483952409378496 reward2: 17.1155843717007
# Episode: 215
# This episode took 25 timesteps and reward1: -55.171470947475136 reward2: 25.1458244181496
# Episode: 216
# This episode took 25 timesteps and reward1: -42.64250857833553 reward2: 9.398810563396657
# Episode: 217
# This episode took 25 timesteps and reward1: -33.683285508067385 reward2: -5.040490418309485
# Episode: 218
# This episode took 25 timesteps and reward1: -40.11834966154898 reward2: 18.096501920690613
# Episode: 219
# This episode took 25 timesteps and reward1: -36.63015569549783 reward2: 7.774085547661504
# Episode: 220
# This episode took 25 timesteps and reward1: -41.250149097702895 reward2: 0.8192428354761936
# Episode: 221
# This episode took 25 timesteps and reward1: -38.71381053626298 reward2: 9.284116995738612
# Episode: 222
# This episode took 25 timesteps and reward1: -39.58321366265671 reward2: 16.51012216645469
# Episode: 223
# This episode took 25 timesteps and reward1: -38.29825513856264 reward2: 7.012688551971525
# Episode: 224
# This episode took 25 timesteps and reward1: -39.60570450391284 reward2: 14.295803992137747
# Episode: 225
# This episode took 25 timesteps and reward1: -37.56629856517683 reward2: 14.145272125888095
# Episode: 226
# This episode took 25 timesteps and reward1: -42.35799470502605 reward2: 1.4546808384316168
# Episode: 227
# This episode took 25 timesteps and reward1: -39.436904111240125 reward2: -0.44648819988191124
# Episode: 228
# This episode took 25 timesteps and reward1: -41.16634414429845 reward2: 16.532637674696424
# Episode: 229
# This episode took 25 timesteps and reward1: -40.012778298328556 reward2: 8.2181281647478
# Episode: 230
# This episode took 25 timesteps and reward1: -37.453231030958804 reward2: -6.928848465495485
# Episode: 231
# This episode took 25 timesteps and reward1: -37.1739660723968 reward2: 5.279747662336757
# Episode: 232
# This episode took 25 timesteps and reward1: -52.08805075078312 reward2: 22.605464961873164
# Episode: 233
# This episode took 25 timesteps and reward1: -45.38169925077596 reward2: 6.952410378090285
# Episode: 234
# This episode took 25 timesteps and reward1: -52.764561465810935 reward2: 18.57251317712695
# Episode: 235
# This episode took 25 timesteps and reward1: -41.93113271120359 reward2: -0.5400410954783765
# Episode: 236
# This episode took 25 timesteps and reward1: -46.461060590518834 reward2: 19.460043788262173
# Episode: 237
# This episode took 25 timesteps and reward1: -33.02298722651956 reward2: 5.732711262457035
# Episode: 238
# This episode took 25 timesteps and reward1: -49.00004355467024 reward2: 15.258532737916605
# Episode: 239
# This episode took 25 timesteps and reward1: -53.27263123687612 reward2: 15.32242462200401
# Episode: 240
# This episode took 25 timesteps and reward1: -48.993573042034015 reward2: 14.282232289302256
# Episode: 241
# This episode took 25 timesteps and reward1: -41.83448549694912 reward2: 11.441796988790074
# Episode: 242
# This episode took 25 timesteps and reward1: -50.9735918531572 reward2: 15.442582480959441
# Episode: 243
# This episode took 25 timesteps and reward1: -47.36724069844742 reward2: 11.195747340982225
# Episode: 244
# This episode took 25 timesteps and reward1: -41.02466283157711 reward2: 11.007125280370223
# Episode: 245
# This episode took 25 timesteps and reward1: -43.84220519356463 reward2: 21.906535405713335
# Episode: 246
# This episode took 25 timesteps and reward1: -50.051756027217564 reward2: 9.71842668903667
# Episode: 247
# This episode took 25 timesteps and reward1: -42.15709643009102 reward2: 2.9651102009163015
# Episode: 248
# This episode took 25 timesteps and reward1: -33.73192586591695 reward2: 2.88804430237919
# Episode: 249
# This episode took 25 timesteps and reward1: -43.35664162373279 reward2: 5.11802656662924
# Episode: 250
# This episode took 25 timesteps and reward1: -48.47511564395969 reward2: 12.661158874595673
# Episode: 251
# This episode took 25 timesteps and reward1: -54.49692675140651 reward2: 21.065475250618075
# Episode: 252
# This episode took 25 timesteps and reward1: -47.52471401207993 reward2: 11.600648833363556
# Episode: 253
# This episode took 25 timesteps and reward1: -47.25513481615501 reward2: 5.485687618595334
# Episode: 254
# This episode took 25 timesteps and reward1: -43.376552485645796 reward2: 6.043066849061784
# Episode: 255
# This episode took 25 timesteps and reward1: -52.95191288135976 reward2: 26.189034840290216
# Episode: 256
# This episode took 25 timesteps and reward1: -53.05867065149008 reward2: 24.976367291958784
# Episode: 257
# This episode took 25 timesteps and reward1: -48.32921107080708 reward2: 15.17682996517137
# Episode: 258
# This episode took 25 timesteps and reward1: -46.489001165607256 reward2: 10.385185148777275
# Episode: 259
# This episode took 25 timesteps and reward1: -48.2418247833242 reward2: 18.59956574929209
# Episode: 260
# This episode took 25 timesteps and reward1: -50.354403440332746 reward2: 20.44879998375128
# Episode: 261
# This episode took 25 timesteps and reward1: -36.72556687356511 reward2: 7.74683648375327
# Episode: 262
# This episode took 25 timesteps and reward1: -46.26556238569729 reward2: 20.131342207825632
# Episode: 263
# This episode took 25 timesteps and reward1: -37.45140642698469 reward2: 10.371177609887772
# Episode: 264
# This episode took 25 timesteps and reward1: -49.51986962279019 reward2: 16.17848691486586
# Episode: 265
# This episode took 25 timesteps and reward1: -43.698674788788516 reward2: 9.530003153898415
# Episode: 266
# This episode took 25 timesteps and reward1: -58.45487557724708 reward2: 26.03645059952311
# Episode: 267
# This episode took 25 timesteps and reward1: -48.71163512303064 reward2: 18.833123384906198
# Episode: 268
# This episode took 25 timesteps and reward1: -51.99600482230196 reward2: 18.28157433746091
# Episode: 269
# This episode took 25 timesteps and reward1: -47.49452468471381 reward2: 17.415521622301533
# Episode: 270
# This episode took 25 timesteps and reward1: -38.16671583068305 reward2: -4.91331175621025
# Episode: 271
# This episode took 25 timesteps and reward1: -47.259188580491106 reward2: 16.558964777334843
# Episode: 272
# This episode took 25 timesteps and reward1: -41.00070351551804 reward2: 15.840047709494947
# Episode: 273
# This episode took 25 timesteps and reward1: -39.070233683541865 reward2: 11.75018461156212
# Episode: 274
# This episode took 25 timesteps and reward1: -43.87701738445689 reward2: 7.826402350022942
# Episode: 275
# This episode took 25 timesteps and reward1: -43.50222188384749 reward2: 12.796943414863808
# Episode: 276
# This episode took 25 timesteps and reward1: -41.11438094935527 reward2: 9.193625730864149
# Episode: 277
# This episode took 25 timesteps and reward1: -45.602536447631444 reward2: 12.576670275330546
# Episode: 278
# This episode took 25 timesteps and reward1: -41.97109468920314 reward2: 11.361276868531894
# Episode: 279
# This episode took 25 timesteps and reward1: -39.87771704967065 reward2: -1.9462360549110838
# Episode: 280
# This episode took 25 timesteps and reward1: -42.90598103152727 reward2: 8.881862856148043
# Episode: 281
# This episode took 25 timesteps and reward1: -37.16263410222902 reward2: 9.002747526182159
# Episode: 282
# This episode took 25 timesteps and reward1: -38.91113188058647 reward2: 7.638888104870031
# Episode: 283
# This episode took 25 timesteps and reward1: -46.476576375737906 reward2: 8.527059706920305
# Episode: 284
# This episode took 25 timesteps and reward1: -47.868238350125274 reward2: 10.297062930513672
# Episode: 285
# This episode took 25 timesteps and reward1: -44.61686548225073 reward2: 5.287888660990566
# Episode: 286
# This episode took 25 timesteps and reward1: -38.425852692666254 reward2: 14.672973264395843
# Episode: 287
# This episode took 25 timesteps and reward1: -46.248008033649874 reward2: 17.086710762635413
# Episode: 288
# This episode took 25 timesteps and reward1: -38.12456358738812 reward2: 13.290872025756912
# Episode: 289
# This episode took 25 timesteps and reward1: -31.86938800656928 reward2: -1.8418133811800006
# Episode: 290
# This episode took 25 timesteps and reward1: -48.18399739436053 reward2: 6.511798327080315
# Episode: 291
# This episode took 25 timesteps and reward1: -47.03707001427544 reward2: 17.407364638131526
# Episode: 292
# This episode took 25 timesteps and reward1: -54.783965285558835 reward2: 23.933902438497377
# Episode: 293
# This episode took 25 timesteps and reward1: -52.732925102918806 reward2: 22.315306468850363
# Episode: 294
# This episode took 25 timesteps and reward1: -29.095741296628766 reward2: 4.4793557117825475
# Episode: 295
# This episode took 25 timesteps and reward1: -45.688232276066095 reward2: 5.576671776901936
# Episode: 296
# This episode took 25 timesteps and reward1: -49.66263086267318 reward2: 21.590398301517816
# Episode: 297
# This episode took 25 timesteps and reward1: -53.16174524863712 reward2: 21.288411386916867
# Episode: 298
# This episode took 25 timesteps and reward1: -51.879051263006815 reward2: 29.507455097672672
# Episode: 299
# This episode took 25 timesteps and reward1: -51.02082483115108 reward2: 12.986284379217874
# Episode: 300
# This episode took 25 timesteps and reward1: -45.92475851471053 reward2: 6.318393075995268
# Episode: 301
# This episode took 25 timesteps and reward1: -35.74875941731426 reward2: -3.245117741699535
# Episode: 302
# This episode took 25 timesteps and reward1: -53.30669585442676 reward2: 15.299255662505704
# Episode: 303
# This episode took 25 timesteps and reward1: -51.45323679258665 reward2: 14.508488766088199
# Episode: 304
# This episode took 25 timesteps and reward1: -46.559887655250144 reward2: 12.107120391576954
# Episode: 305
# This episode took 25 timesteps and reward1: -52.517840225493714 reward2: 22.631985277720595
# Episode: 306
# This episode took 25 timesteps and reward1: -52.34742231557152 reward2: 10.380810109872
# Episode: 307
# This episode took 25 timesteps and reward1: -44.96266366409827 reward2: 14.43564007247542
# Episode: 308
# This episode took 25 timesteps and reward1: -53.554222316687195 reward2: 23.202223614587933
# Episode: 309
# This episode took 25 timesteps and reward1: -47.58538963486867 reward2: 20.74521556806198
# Episode: 310
# This episode took 25 timesteps and reward1: -41.00607887481615 reward2: 10.466009203235947
# Episode: 311
# This episode took 25 timesteps and reward1: -54.71604894514124 reward2: 20.928473997675358
# Episode: 312
# This episode took 25 timesteps and reward1: -45.488735582570285 reward2: 20.80708947477248
# Episode: 313
# This episode took 25 timesteps and reward1: -50.38131756138519 reward2: 26.333198798592573
# Episode: 314
# This episode took 25 timesteps and reward1: -44.968255223073875 reward2: 17.379177046051932
# Episode: 315
# This episode took 25 timesteps and reward1: -49.236259119193335 reward2: 10.840442983695343
# Episode: 316
# This episode took 25 timesteps and reward1: -43.73851633775406 reward2: 12.404325580694511
# Episode: 317
# This episode took 25 timesteps and reward1: -39.90111220551641 reward2: 11.117869090218862
# Episode: 318
# This episode took 25 timesteps and reward1: -48.73357346945974 reward2: 27.963032912328266
# Episode: 319
# This episode took 25 timesteps and reward1: -53.66258765840202 reward2: 2.642024470564419
# Episode: 320
# This episode took 25 timesteps and reward1: -41.418414875153346 reward2: 9.059757049094372
# Episode: 321
# This episode took 25 timesteps and reward1: -51.51480881203717 reward2: 14.329162558530479
# Episode: 322
# This episode took 25 timesteps and reward1: -46.720172428007935 reward2: 9.307911127374366
# Episode: 323
# This episode took 25 timesteps and reward1: -43.39457835382764 reward2: 14.294628692008574
# Episode: 324
# This episode took 25 timesteps and reward1: -56.7403166849761 reward2: 19.712634631692712
# Episode: 325
# This episode took 25 timesteps and reward1: -35.854895762345166 reward2: 1.4622746868168708
# Episode: 326
# This episode took 25 timesteps and reward1: -34.86724833431975 reward2: 5.308501320408267
# Episode: 327
# This episode took 25 timesteps and reward1: -43.024370789545316 reward2: 3.293886527116512
# Episode: 328
# This episode took 25 timesteps and reward1: -35.598637254933806 reward2: 11.455674569443675
# Episode: 329
# This episode took 25 timesteps and reward1: -40.22005882203168 reward2: 6.874601921517301
# Episode: 330
# This episode took 25 timesteps and reward1: -55.98942486814715 reward2: 27.657400869923766
# Episode: 331
# This episode took 25 timesteps and reward1: -41.90374494879144 reward2: 8.9847193116291
# Episode: 332
# This episode took 25 timesteps and reward1: -38.665985093087336 reward2: 17.668591880467094
# Episode: 333
# This episode took 25 timesteps and reward1: -51.51157347148703 reward2: 7.737197459716027
# Episode: 334
# This episode took 25 timesteps and reward1: -52.82352223377608 reward2: 24.8744350871005
# Episode: 335
# This episode took 25 timesteps and reward1: -34.752968228415774 reward2: -0.510897379877497
# Episode: 336
# This episode took 25 timesteps and reward1: -47.178680154611214 reward2: 13.336902368794291
# Episode: 337
# This episode took 25 timesteps and reward1: -51.01693390446909 reward2: 10.188084351048305
# Episode: 338
# This episode took 25 timesteps and reward1: -41.45804766241485 reward2: -0.49601127434089176
# Episode: 339
# This episode took 25 timesteps and reward1: -47.97217143824785 reward2: 17.238715883808307
# Episode: 340
# This episode took 25 timesteps and reward1: -40.089667311363755 reward2: 5.841812556924249
# Episode: 341
# This episode took 25 timesteps and reward1: -46.125822289034225 reward2: 21.882368126244227
# Episode: 342
# This episode took 25 timesteps and reward1: -55.30831232328223 reward2: 19.780115960194895
# Episode: 343
# This episode took 25 timesteps and reward1: -40.63754178530895 reward2: 6.253306609802708
# Episode: 344
# This episode took 25 timesteps and reward1: -44.49520224782219 reward2: 14.381084450436177
# Episode: 345
# This episode took 25 timesteps and reward1: -50.56665613623271 reward2: 22.76516233569224
# Episode: 346
# This episode took 25 timesteps and reward1: -56.4047076086234 reward2: 25.96806608619209
# Episode: 347
# This episode took 25 timesteps and reward1: -47.8602642375673 reward2: 25.439483182344294
# Episode: 348
# This episode took 25 timesteps and reward1: -45.19084753488919 reward2: 8.476420472526994
# Episode: 349
# This episode took 25 timesteps and reward1: -39.22541553972236 reward2: 4.002800740697021
# Episode: 350
# This episode took 25 timesteps and reward1: -53.714600272236666 reward2: 13.8592134375388
# Episode: 351
# This episode took 25 timesteps and reward1: -40.89462683069603 reward2: 8.883043516105225
# Episode: 352
# This episode took 25 timesteps and reward1: -47.79933542935167 reward2: 9.712866420104753
# Episode: 353
# This episode took 25 timesteps and reward1: -42.89404417911926 reward2: 9.480967943243709
# Episode: 354
# This episode took 25 timesteps and reward1: -46.208870705005424 reward2: 21.15471430373546
# Episode: 355
# This episode took 25 timesteps and reward1: -50.47344584334205 reward2: 23.78775067733227
# Episode: 356
# This episode took 25 timesteps and reward1: -54.15834958672908 reward2: 25.03837129020743
# Episode: 357
# This episode took 25 timesteps and reward1: -59.52374178488921 reward2: 16.921668981365343
# Episode: 358
# This episode took 25 timesteps and reward1: -49.65164886087217 reward2: 11.851237779219868
# Episode: 359
# This episode took 25 timesteps and reward1: -43.2345246442066 reward2: 7.838704710358247
# Episode: 360
# This episode took 25 timesteps and reward1: -48.07014282223562 reward2: 10.912213786599896
# Episode: 361
# This episode took 25 timesteps and reward1: -52.259208644040115 reward2: 19.15308405121286
# Episode: 362
# This episode took 25 timesteps and reward1: -56.60805082920102 reward2: 19.36006541784468
# Episode: 363
# This episode took 25 timesteps and reward1: -43.5973054279213 reward2: 6.909972518075259
# Episode: 364
# This episode took 25 timesteps and reward1: -39.21441097637369 reward2: 7.573314734487994
# Episode: 365
# This episode took 25 timesteps and reward1: -61.49334400346192 reward2: 24.199581627861885
# Episode: 366
# This episode took 25 timesteps and reward1: -44.48809533455721 reward2: 4.821472897632203
# Episode: 367
# This episode took 25 timesteps and reward1: -47.68918300950678 reward2: 18.09451118261615
# Episode: 368
# This episode took 25 timesteps and reward1: -37.17303504077721 reward2: 2.7117187833188483
# Episode: 369
# This episode took 25 timesteps and reward1: -42.515899441444425 reward2: 13.877597793692246
# Episode: 370
# This episode took 25 timesteps and reward1: -46.641895742786474 reward2: 7.1958903672298975
# Episode: 371
# This episode took 25 timesteps and reward1: -51.94919549742914 reward2: 14.019973655082424
# Episode: 372
# This episode took 25 timesteps and reward1: -37.72531692991008 reward2: 6.911556043848885
# Episode: 373
# This episode took 25 timesteps and reward1: -38.6331399980361 reward2: 12.770787843322056
# Episode: 374
# This episode took 25 timesteps and reward1: -49.82640387178952 reward2: 18.745169171207237
# Episode: 375
# This episode took 25 timesteps and reward1: -40.59200562345274 reward2: 3.6057897495025695
# Episode: 376
# This episode took 25 timesteps and reward1: -52.378200991761155 reward2: 9.622098275035658
# Episode: 377
# This episode took 25 timesteps and reward1: -40.40608725863416 reward2: 8.661059336781289
# Episode: 378
# This episode took 25 timesteps and reward1: -34.49515762780528 reward2: -4.371762281808257
# Episode: 379
# This episode took 25 timesteps and reward1: -37.20840187292694 reward2: 9.732814582813774
# Episode: 380
# This episode took 25 timesteps and reward1: -54.38377589463419 reward2: 25.29270899235682
# Episode: 381
# This episode took 25 timesteps and reward1: -41.441815966737515 reward2: 0.19564603213990472
# Episode: 382
# This episode took 25 timesteps and reward1: -43.52796629813483 reward2: 5.419686962111491
# Episode: 383
# This episode took 25 timesteps and reward1: -53.369412202974935 reward2: 22.741030597105755
# Episode: 384
# This episode took 25 timesteps and reward1: -42.00796343774098 reward2: 9.12586007219091
# Episode: 385
# This episode took 25 timesteps and reward1: -47.88646862787943 reward2: 13.879314893771033
# Episode: 386
# This episode took 25 timesteps and reward1: -54.53756898186045 reward2: 29.325150468295714
# Episode: 387
# This episode took 25 timesteps and reward1: -46.824657560601395 reward2: 5.952723480859149
# Episode: 388
# This episode took 25 timesteps and reward1: -28.64923444193523 reward2: -3.6415352084400614
# Episode: 389
# This episode took 25 timesteps and reward1: -47.747810645443614 reward2: 19.037507919550002
# Episode: 390
# This episode took 25 timesteps and reward1: -51.770609231916985 reward2: 16.115083246669272
# Episode: 391
# This episode took 25 timesteps and reward1: -39.25206670268036 reward2: 3.769223848346286
# Episode: 392
# This episode took 25 timesteps and reward1: -52.03587165825792 reward2: 13.109313071283049
# Episode: 393
# This episode took 25 timesteps and reward1: -42.15004508745468 reward2: 5.398112505554657
# Episode: 394
# This episode took 25 timesteps and reward1: -44.971344503571515 reward2: 19.436285650591028
# Episode: 395
# This episode took 25 timesteps and reward1: -52.551514251787246 reward2: 17.433278374863928
# Episode: 396
# This episode took 25 timesteps and reward1: -37.76056323513554 reward2: 16.178550481101595
# Episode: 397
# This episode took 25 timesteps and reward1: -43.50492823391163 reward2: 12.924958925772858
# Episode: 398
# This episode took 25 timesteps and reward1: -46.127827647907175 reward2: 23.06828560734282
# Episode: 399
# This episode took 25 timesteps and reward1: -31.935997190331605 reward2: -0.557177266957426
# Episode: 400
# This episode took 25 timesteps and reward1: -50.2013345468417 reward2: 13.302022193517015
# Episode: 401
# This episode took 25 timesteps and reward1: -41.095817981159094 reward2: 8.605658652071126
# Episode: 402
# This episode took 25 timesteps and reward1: -50.00587459534047 reward2: 25.036216134550475
# Episode: 403
# This episode took 25 timesteps and reward1: -43.742272214450395 reward2: 21.721596071474497
# Episode: 404
# This episode took 25 timesteps and reward1: -47.69094283723553 reward2: 15.205582886555508
# Episode: 405
# This episode took 25 timesteps and reward1: -36.43170203148552 reward2: 11.437461298301255
# Episode: 406
# This episode took 25 timesteps and reward1: -37.87929307889239 reward2: 8.849388000156356
# Episode: 407
# This episode took 25 timesteps and reward1: -52.71506413405594 reward2: 23.64156008300691
# Episode: 408
# This episode took 25 timesteps and reward1: -29.838174568397783 reward2: -10.1209828123596
# Episode: 409
# This episode took 25 timesteps and reward1: -47.38079838014892 reward2: 24.60956754033641
# Episode: 410
# This episode took 25 timesteps and reward1: -46.875089887485814 reward2: 18.258528279132147
# Episode: 411
# This episode took 25 timesteps and reward1: -42.30307171279559 reward2: 10.420681798676869
# Episode: 412
# This episode took 25 timesteps and reward1: -51.711290564030314 reward2: 24.416672029816432
# Episode: 413
# This episode took 25 timesteps and reward1: -43.95647205964423 reward2: 12.64265199567204
# Episode: 414
# This episode took 25 timesteps and reward1: -42.66467992625113 reward2: 13.493269362235523
# Episode: 415
# This episode took 25 timesteps and reward1: -41.4269130936662 reward2: 5.958866996725468
# Episode: 416
# This episode took 25 timesteps and reward1: -51.439973871304915 reward2: 14.622628876237869
# Episode: 417
# This episode took 25 timesteps and reward1: -39.34487944837912 reward2: 6.825179834997272
# Episode: 418
# This episode took 25 timesteps and reward1: -48.91842764015113 reward2: 17.00665205860391
# Episode: 419
# This episode took 25 timesteps and reward1: -45.24661124089965 reward2: 13.317648734515721
# Episode: 420
# This episode took 25 timesteps and reward1: -45.125363567538834 reward2: 18.561099480898143
# Episode: 421
# This episode took 25 timesteps and reward1: -45.540033302148856 reward2: 14.326299542754995
# Episode: 422
# This episode took 25 timesteps and reward1: -41.88483039540856 reward2: -4.009878228962048
# Episode: 423
# This episode took 25 timesteps and reward1: -39.54906474422672 reward2: 14.908940974484619
# Episode: 424
# This episode took 25 timesteps and reward1: -40.561189317628 reward2: 18.60682951983283
# Episode: 425
# This episode took 25 timesteps and reward1: -53.45870716158185 reward2: 22.330212471572292
# Episode: 426
# This episode took 25 timesteps and reward1: -47.64734125544414 reward2: 21.172150462023218
# Episode: 427
# This episode took 25 timesteps and reward1: -35.5719232804602 reward2: 5.541995896890635
# Episode: 428
# This episode took 25 timesteps and reward1: -34.10191086267429 reward2: -10.356670143830229
# Episode: 429
# This episode took 25 timesteps and reward1: -52.543134032193755 reward2: 21.83062020633026
# Episode: 430
# This episode took 25 timesteps and reward1: -37.11149218497078 reward2: -1.9289077415307285
# Episode: 431
# This episode took 25 timesteps and reward1: -50.804742737755824 reward2: 20.215092625038057
# Episode: 432
# This episode took 25 timesteps and reward1: -50.080458684397804 reward2: 3.3227974378605234
# Episode: 433
# This episode took 25 timesteps and reward1: -41.01401773617702 reward2: 5.3992738361277315
# Episode: 434
# This episode took 25 timesteps and reward1: -59.455511327149594 reward2: 24.933035116097834
# Episode: 435
# This episode took 25 timesteps and reward1: -52.1808318119461 reward2: 8.214070229987
# Episode: 436
# This episode took 25 timesteps and reward1: -51.71813941683187 reward2: 15.929979554350929
# Episode: 437
# This episode took 25 timesteps and reward1: -44.491350896723496 reward2: 18.736563957102074
# Episode: 438
# This episode took 25 timesteps and reward1: -39.334418626720996 reward2: -10.110029132867535
# Episode: 439
# This episode took 25 timesteps and reward1: -45.52694081892493 reward2: 25.403090500393784
# Episode: 440
# This episode took 25 timesteps and reward1: -44.80748549141032 reward2: 10.118732549270888
# Episode: 441
# This episode took 25 timesteps and reward1: -47.22967498114636 reward2: 10.129338739251894
# Episode: 442
# This episode took 25 timesteps and reward1: -46.28502624208829 reward2: 8.624928193764681
# Episode: 443
# This episode took 25 timesteps and reward1: -42.579918451587154 reward2: 12.495702057621491
# Episode: 444
# This episode took 25 timesteps and reward1: -45.09857387339673 reward2: 7.033756545885053
# Episode: 445
# This episode took 25 timesteps and reward1: -42.121480958936274 reward2: 6.795349080098585
# Episode: 446
# This episode took 25 timesteps and reward1: -48.15410864949431 reward2: 17.38954547365472
# Episode: 447
# This episode took 25 timesteps and reward1: -53.85495784984942 reward2: 17.136259799713756
# Episode: 448
# This episode took 25 timesteps and reward1: -43.65741862211991 reward2: 13.554474300990616
# Episode: 449
# This episode took 25 timesteps and reward1: -33.95533605952736 reward2: -2.6013544122945236
# Episode: 450
# This episode took 25 timesteps and reward1: -40.69843614483429 reward2: 2.356702508836162
# Episode: 451
# This episode took 25 timesteps and reward1: -41.511802963836345 reward2: 10.669984020328831
# Episode: 452
# This episode took 25 timesteps and reward1: -48.52059177699284 reward2: 18.611458871187835
# Episode: 453
# This episode took 25 timesteps and reward1: -38.0029304147572 reward2: 4.706965620927853
# Episode: 454
# This episode took 25 timesteps and reward1: -47.88948610516018 reward2: 14.62364963877872
# Episode: 455
# This episode took 25 timesteps and reward1: -45.826665076799394 reward2: 20.387445386518202
# Episode: 456
# This episode took 25 timesteps and reward1: -46.927748804415025 reward2: 25.354997333168313
# Episode: 457
# This episode took 25 timesteps and reward1: -43.458751284180195 reward2: 7.378414642065266
# Episode: 458
# This episode took 25 timesteps and reward1: -48.66564145100278 reward2: 15.455208316002656
# Episode: 459
# This episode took 25 timesteps and reward1: -32.37574403646418 reward2: 1.1579057668397539
# Episode: 460
# This episode took 25 timesteps and reward1: -42.55830337913418 reward2: 7.181764460647793
# Episode: 461
# This episode took 25 timesteps and reward1: -54.28295231512252 reward2: 16.709885279541922
# Episode: 462
# This episode took 25 timesteps and reward1: -49.169351771621194 reward2: 20.81020231896206
# Episode: 463
# ...
# Episode: 2848
# This episode took 25 timesteps and reward1: -48.2603963185681 reward2: 17.745147426636954
# Episode: 2849
# This episode took 25 timesteps and reward1: -42.36138414807197 reward2: 13.973241908071806
# Episode: 2850
# This episode took 25 timesteps and reward1: -50.14983362779995 reward2: 20.138582515471988
# Episode: 2851
# This episode took 25 timesteps and reward1: -53.09913181235752 reward2: 28.70880622549448
# Episode: 2852
# This episode took 25 timesteps and reward1: -49.75285349609646 reward2: 15.238906527171968
# Episode: 2853
# This episode took 25 timesteps and reward1: -51.42523008753897 reward2: 27.502028896775478
# Episode: 2854
# This episode took 25 timesteps and reward1: -56.89461450119202 reward2: 30.769817398010517
# Episode: 2855
# This episode took 25 timesteps and reward1: -42.017056630411304 reward2: 21.191422398512334
# Episode: 2856
# This episode took 25 timesteps and reward1: -42.23930975991397 reward2: 17.286165049576415
# Episode: 2857
# This episode took 25 timesteps and reward1: -44.725612187420786 reward2: 15.265095365538837
# Episode: 2858
# This episode took 25 timesteps and reward1: -41.09267547416194 reward2: 20.905916335142273
# Episode: 2859
# This episode took 25 timesteps and reward1: -40.9424679623009 reward2: 12.690700763890877
# Episode: 2860
# This episode took 25 timesteps and reward1: -42.30923226627563 reward2: 9.309076489861221
# Episode: 2861
# This episode took 25 timesteps and reward1: -44.340530481445334 reward2: 14.446929881595247
# Episode: 2862
# This episode took 25 timesteps and reward1: -48.97261302614134 reward2: 22.677985061209704
# Episode: 2863
# This episode took 25 timesteps and reward1: -53.3273239341091 reward2: 26.791288430650617
# Episode: 2864
# This episode took 25 timesteps and reward1: -43.16762411746509 reward2: 16.318813710333803
# Episode: 2865
# This episode took 25 timesteps and reward1: -42.04523613196583 reward2: 6.047134960848132
# Episode: 2866
# This episode took 25 timesteps and reward1: -47.911366586045546 reward2: 25.78690037246002
# Episode: 2867
# This episode took 25 timesteps and reward1: -43.2282360502602 reward2: 14.701637458704576
# Episode: 2868
# This episode took 25 timesteps and reward1: -41.506806336707804 reward2: 15.528428437452162
# Episode: 2869
# This episode took 25 timesteps and reward1: -59.5400093672338 reward2: 38.50095798184437
# Episode: 2870
# This episode took 25 timesteps and reward1: -46.58264560806233 reward2: 14.112608836377758
# Episode: 2871
# This episode took 25 timesteps and reward1: -46.63645590090819 reward2: 22.3203549318535
# Episode: 2872
# This episode took 25 timesteps and reward1: -49.995011050537975 reward2: 18.89709126764206
# Episode: 2873
# This episode took 25 timesteps and reward1: -49.35467225733434 reward2: 21.71509714977133
# Episode: 2874
# This episode took 25 timesteps and reward1: -42.085327154904135 reward2: 14.312710020788817
# Episode: 2875
# This episode took 25 timesteps and reward1: -47.05153947289484 reward2: 21.617632356762122
# Episode: 2876
# This episode took 25 timesteps and reward1: -45.506448541888524 reward2: 19.759620665886676
# Episode: 2877
# This episode took 25 timesteps and reward1: -45.11554455428797 reward2: 21.485437125769398
# Episode: 2878
# This episode took 25 timesteps and reward1: -40.76495317022458 reward2: 15.29578950589829
# Episode: 2879
# This episode took 25 timesteps and reward1: -41.640466576455275 reward2: 12.058655722364183
# Episode: 2880
# This episode took 25 timesteps and reward1: -48.16943074388987 reward2: 21.221438409268647
# Episode: 2881
# This episode took 25 timesteps and reward1: -47.62588863615081 reward2: 21.117597207256544
# Episode: 2882
# This episode took 25 timesteps and reward1: -52.4430739442508 reward2: 31.93648238975325
# Episode: 2883
# This episode took 25 timesteps and reward1: -47.42647830241769 reward2: 22.185131473601807
# Episode: 2884
# This episode took 25 timesteps and reward1: -52.576736604223925 reward2: 27.12641929639885
# Episode: 2885
# This episode took 25 timesteps and reward1: -45.39435034377391 reward2: 7.527048745700922
# Episode: 2886
# This episode took 25 timesteps and reward1: -46.670150558015685 reward2: 18.005505960624788
# Episode: 2887
# This episode took 25 timesteps and reward1: -54.80654201304816 reward2: 30.086021852307653
# Episode: 2888
# This episode took 25 timesteps and reward1: -56.88043848877182 reward2: 31.832162175207166
# Episode: 2889
# This episode took 25 timesteps and reward1: -49.236799986392 reward2: 29.1538330520969
# Episode: 2890
# This episode took 25 timesteps and reward1: -52.238989407682965 reward2: 27.121102215319766
# Episode: 2891
# This episode took 25 timesteps and reward1: -53.923345116783096 reward2: 10.675133737391992
# Episode: 2892
# This episode took 25 timesteps and reward1: -47.45474756618875 reward2: 16.925884071682187
# Episode: 2893
# This episode took 25 timesteps and reward1: -55.64007004713507 reward2: 29.864327001722287
# Episode: 2894
# This episode took 25 timesteps and reward1: -52.4929529497852 reward2: 25.989961508679304
# Episode: 2895
# This episode took 25 timesteps and reward1: -45.700592519751396 reward2: 24.666516709577326
# Episode: 2896
# This episode took 25 timesteps and reward1: -48.84296099026605 reward2: 21.386415790188757
# Episode: 2897
# This episode took 25 timesteps and reward1: -42.437502797826184 reward2: 14.928397469542146
# Episode: 2898
# This episode took 25 timesteps and reward1: -49.75102652819926 reward2: 18.812615607898394
# Episode: 2899
# This episode took 25 timesteps and reward1: -48.35455168030613 reward2: 15.660833789986945
# Episode: 2900
# This episode took 25 timesteps and reward1: -40.16615555000901 reward2: 12.709584015944637
# Episode: 2901
# This episode took 25 timesteps and reward1: -50.85384445124485 reward2: 30.43233187068666
# Episode: 2902
# This episode took 25 timesteps and reward1: -53.75739137235899 reward2: 17.12634792518103
# Episode: 2903
# This episode took 25 timesteps and reward1: -50.92512828733438 reward2: 15.642523636193168
# Episode: 2904
# This episode took 25 timesteps and reward1: -49.574920112112984 reward2: 20.216059926685954
# Episode: 2905
# This episode took 25 timesteps and reward1: -47.85036082022387 reward2: 17.859352601672654
# Episode: 2906
# This episode took 25 timesteps and reward1: -46.68369653657532 reward2: 13.06971077347509
# Episode: 2907
# This episode took 25 timesteps and reward1: -45.68786269976447 reward2: 15.085371662745853
# Episode: 2908
# This episode took 25 timesteps and reward1: -46.87181663790294 reward2: 20.82353816086313
# Episode: 2909
# This episode took 25 timesteps and reward1: -50.81731900053544 reward2: 25.897403960913245
# Episode: 2910
# This episode took 25 timesteps and reward1: -56.77562313406265 reward2: 35.05484743871565
# Episode: 2911
# This episode took 25 timesteps and reward1: -42.97930502182756 reward2: 19.611341843361586
# Episode: 2912
# This episode took 25 timesteps and reward1: -61.43767623852014 reward2: 29.58471228286917
# Episode: 2913
# This episode took 25 timesteps and reward1: -48.116374846859934 reward2: 20.996236367304036
# Episode: 2914
# This episode took 25 timesteps and reward1: -45.459708996784116 reward2: 9.917767985259886
# Episode: 2915
# This episode took 25 timesteps and reward1: -44.797014161618804 reward2: 20.322086447592522
# Episode: 2916
# This episode took 25 timesteps and reward1: -48.85060533741927 reward2: 25.290214370200587
# Episode: 2917
# This episode took 25 timesteps and reward1: -52.25301884766754 reward2: 21.527247102919805
# Episode: 2918
# This episode took 25 timesteps and reward1: -50.990355331480586 reward2: 23.578870857306704
# Episode: 2919
# This episode took 25 timesteps and reward1: -51.11080565256081 reward2: 27.02466069706188
# Episode: 2920
# This episode took 25 timesteps and reward1: -49.1071340312345 reward2: 26.55156006244635
# Episode: 2921
# This episode took 25 timesteps and reward1: -39.439297597782186 reward2: 15.439028991676098
# Episode: 2922
# This episode took 25 timesteps and reward1: -41.624812969905705 reward2: 16.4473687089257
# Episode: 2923
# This episode took 25 timesteps and reward1: -44.88951830557131 reward2: 19.522471049621377
# Episode: 2924
# This episode took 25 timesteps and reward1: -43.84869272864667 reward2: 17.23678332755624
# Episode: 2925
# This episode took 25 timesteps and reward1: -42.76266779945995 reward2: 13.665777590993901
# Episode: 2926
# This episode took 25 timesteps and reward1: -56.597847998494885 reward2: 28.79789430946297
# Episode: 2927
# This episode took 25 timesteps and reward1: -55.30630889213023 reward2: 27.394242354507128
# Episode: 2928
# This episode took 25 timesteps and reward1: -52.65321431467228 reward2: 29.425144638825287
# Episode: 2929
# This episode took 25 timesteps and reward1: -52.052618129727506 reward2: 22.71715168886952
# Episode: 2930
# This episode took 25 timesteps and reward1: -45.18147023438668 reward2: 19.763412413345772
# Episode: 2931
# This episode took 25 timesteps and reward1: -48.045728903924605 reward2: 24.19840648001795
# Episode: 2932
# This episode took 25 timesteps and reward1: -52.58300971628322 reward2: 19.003171899885675
# Episode: 2933
# This episode took 25 timesteps and reward1: -37.51289269762439 reward2: 11.023745087464157
# Episode: 2934
# This episode took 25 timesteps and reward1: -60.94862175785763 reward2: 35.77351871220999
# Episode: 2935
# This episode took 25 timesteps and reward1: -48.308880760630025 reward2: 19.986529605245412
# Episode: 2936
# This episode took 25 timesteps and reward1: -42.0231783927733 reward2: 18.295665352883333
# Episode: 2937
# This episode took 25 timesteps and reward1: -51.151871505267444 reward2: 27.549997870071934
# Episode: 2938
# This episode took 25 timesteps and reward1: -46.53597863783574 reward2: 23.455701446699738
# Episode: 2939
# This episode took 25 timesteps and reward1: -44.72821462123571 reward2: 17.71639401383546
# Episode: 2940
# This episode took 25 timesteps and reward1: -49.64733951488887 reward2: 17.05559493450349
# Episode: 2941
# This episode took 25 timesteps and reward1: -53.34353325296936 reward2: 31.20912341382441
# Episode: 2942
# This episode took 25 timesteps and reward1: -55.66779485951267 reward2: 31.605359777352472
# Episode: 2943
# This episode took 25 timesteps and reward1: -50.09865044128703 reward2: 25.248480866133203
# Episode: 2944
# This episode took 25 timesteps and reward1: -45.80208350380125 reward2: 15.169475676460783
# Episode: 2945
# This episode took 25 timesteps and reward1: -39.339360881173185 reward2: 12.538341506572513
# Episode: 2946
# This episode took 25 timesteps and reward1: -43.24842219710468 reward2: 8.99404410423742
# Episode: 2947
# This episode took 25 timesteps and reward1: -52.10393933952969 reward2: 21.714224679759468
# Episode: 2948
# This episode took 25 timesteps and reward1: -38.12283450059665 reward2: 14.669539538426832
# Episode: 2949
# This episode took 25 timesteps and reward1: -44.80004413820905 reward2: 19.054739603494934
# Episode: 2950
# This episode took 25 timesteps and reward1: -47.494974353281016 reward2: 23.8263581109598
# Episode: 2951
# This episode took 25 timesteps and reward1: -43.31979701131266 reward2: 13.088428906757269
# Episode: 2952
# This episode took 25 timesteps and reward1: -55.851105039197336 reward2: 33.4045829608493
# Episode: 2953
# This episode took 25 timesteps and reward1: -44.31966824090468 reward2: 18.770761011624156
# Episode: 2954
# This episode took 25 timesteps and reward1: -42.44407064890576 reward2: 9.654580684987135
# Episode: 2955
# This episode took 25 timesteps and reward1: -50.10239528483409 reward2: 24.7943592657593
# Episode: 2956
# This episode took 25 timesteps and reward1: -43.59912490459236 reward2: 14.77185407826455
# Episode: 2957
# This episode took 25 timesteps and reward1: -45.69816876804621 reward2: 11.269230488502469
# Episode: 2958
# This episode took 25 timesteps and reward1: -46.63324412973062 reward2: 20.136856604560155
# Episode: 2959
# This episode took 25 timesteps and reward1: -43.78814730718302 reward2: 17.06703724023118
# Episode: 2960
# This episode took 25 timesteps and reward1: -46.285746186352064 reward2: 20.934172557520906
# Episode: 2961
# This episode took 25 timesteps and reward1: -46.070780636455304 reward2: 17.807451669169012
# Episode: 2962
# This episode took 25 timesteps and reward1: -41.128524062173206 reward2: 12.975575701422308
# Episode: 2963
# This episode took 25 timesteps and reward1: -43.166038631402785 reward2: 10.902081364892268
# Episode: 2964
# This episode took 25 timesteps and reward1: -38.93723806428338 reward2: 11.538400055531495
# Episode: 2965
# This episode took 25 timesteps and reward1: -46.38566297633991 reward2: 14.155784305681289
# Episode: 2966
# This episode took 25 timesteps and reward1: -40.64987669351051 reward2: 1.684961553906193
# Episode: 2967
# This episode took 25 timesteps and reward1: -52.92992876938261 reward2: 31.397570914420395
# Episode: 2968
# This episode took 25 timesteps and reward1: -43.84706552750143 reward2: 18.792529795123937
# Episode: 2969
# This episode took 25 timesteps and reward1: -48.28379351566391 reward2: 10.369228835206956
# Episode: 2970
# This episode took 25 timesteps and reward1: -44.5914075347066 reward2: 15.558970469110491
# Episode: 2971
# This episode took 25 timesteps and reward1: -49.92971371248674 reward2: 29.273451960653357
# Episode: 2972
# This episode took 25 timesteps and reward1: -48.62223457995054 reward2: 2.0497694307510734
# Episode: 2973
# This episode took 25 timesteps and reward1: -53.10949033412659 reward2: 16.722472954153588
# Episode: 2974
# This episode took 25 timesteps and reward1: -47.26324641309106 reward2: 21.026731048616114
# Episode: 2975
# This episode took 25 timesteps and reward1: -50.47813213722251 reward2: 21.109875298519242
# Episode: 2976
# This episode took 25 timesteps and reward1: -43.629394073323496 reward2: 15.973244966443032
# Episode: 2977
# This episode took 25 timesteps and reward1: -45.952885785039086 reward2: 20.58732682607675
# Episode: 2978
# This episode took 25 timesteps and reward1: -48.16473404375676 reward2: 24.454114321126294
# Episode: 2979
# This episode took 25 timesteps and reward1: -52.77896928651061 reward2: 27.72465324243232
# Episode: 2980
# This episode took 25 timesteps and reward1: -51.7970025126803 reward2: 22.67958393696815
# Episode: 2981
# This episode took 25 timesteps and reward1: -42.213270705164064 reward2: 17.99849898369521
# Episode: 2982
# This episode took 25 timesteps and reward1: -43.909775115190634 reward2: 14.605311288059148
# Episode: 2983
# This episode took 25 timesteps and reward1: -55.142447520656525 reward2: 25.7896757298781
# Episode: 2984
# This episode took 25 timesteps and reward1: -56.2003374196888 reward2: 31.982629127633835
# Episode: 2985
# This episode took 25 timesteps and reward1: -52.21726020947483 reward2: 20.501236594702743
# Episode: 2986
# This episode took 25 timesteps and reward1: -47.904513702151455 reward2: 10.020457414438125
# Episode: 2987
# This episode took 25 timesteps and reward1: -50.97214121191715 reward2: 27.051356678419644
# Episode: 2988
# This episode took 25 timesteps and reward1: -47.091579556675306 reward2: 16.554536012423554
# Episode: 2989
# This episode took 25 timesteps and reward1: -51.69108620718673 reward2: 27.916154965319006
# Episode: 2990
# This episode took 25 timesteps and reward1: -38.82533315620753 reward2: 11.771106290364905
# Episode: 2991
# This episode took 25 timesteps and reward1: -35.254163157578844 reward2: -0.9702227492911724
# Episode: 2992
# This episode took 25 timesteps and reward1: -45.260345589623824 reward2: 19.858018104671913
# Episode: 2993
# This episode took 25 timesteps and reward1: -43.895056630412526 reward2: 17.815512600549052
# Episode: 2994
# This episode took 25 timesteps and reward1: -51.84077808517565 reward2: 28.549667588761817
# Episode: 2995
# This episode took 25 timesteps and reward1: -50.82746845432399 reward2: 23.79364069576635
# Episode: 2996
# This episode took 25 timesteps and reward1: -39.88655254651361 reward2: 12.463534924075072
# Episode: 2997
# This episode took 25 timesteps and reward1: -45.634032337373355 reward2: 18.039609916065924
# Episode: 2998
# This episode took 25 timesteps and reward1: -46.34212182138449 reward2: 25.019867124218116
# Episode: 2999
# This episode took 25 timesteps and reward1: -52.45187128731653 reward2: 22.731514897891568

# %%
import matplotlib.pyplot as plt

def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n
plt.plot(moving_average(r1_minmax, n=100), label = 'Adversary agent')
plt.plot(moving_average(r2_minmax, n=100), label='Good agent')
plt.xlabel("Episode")
plt.ylabel("Average Reward")
plt.title("Average Reward per Episode for MINMAX Algorithm")
plt.legend()
plt.plot()
# Out:
# []

# %%
def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n


plt.plot(moving_average(total_rewards, n=100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       3     ret[n:] = ret[n:] - ret[:-n]
#       4     return ret[n - 1:] / n
# ----> 7 plt.plot(moving_average(total_rewards, n=100))
#
# NameError: name 'total_rewards' is not defined
